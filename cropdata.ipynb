# %%
# !python3 'yolov5/detect.py' --weights 'yolov5/runs/train/exp/weights/best.pt' --source 'dataset/images/train'
# Out:
# detect: weights=['yolov5/runs/train/exp/weights/best.pt'], source=dataset/images/train, data=yolov5/data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=yolov5/runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-215-ga6659d0 Python-3.8.10 torch-1.10.0+cu113 CUDA:0 (NVIDIA GeForce RTX 4090, 24217MiB)
#
# Fusing layers...
# whale_model_l summary: 267 layers, 46108278 parameters, 0 gradients, 107.6 GFLOPs
# image 1/9850 /root/autodl-tmp/whale_tail/dataset/images/train/00022e1a.jpg: 480x640 (no detections), 12.1ms
# image 2/9850 /root/autodl-tmp/whale_tail/dataset/images/train/000466c4.jpg: 448x640 (no detections), 11.6ms
# ...
