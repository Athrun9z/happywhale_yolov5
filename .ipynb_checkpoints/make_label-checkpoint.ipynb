# %%
import pandas as pd
import numpy as np
from tqdm import tqdm
import cv2
import matplotlib.pyplot as plt

# %%
train = pd.read_csv('train.csv')

# %%
train
# Out:
#              Image         Id
# 0     00022e1a.jpg  w_e15442c
# 1     000466c4.jpg  w_1287fbc
# 2     00087b01.jpg  w_da2efe0
# 3     001296d5.jpg  w_19e5482
# 4     0014cfdf.jpg  w_f22f3e3
# ...            ...        ...
# 9845  ffe5c306.jpg  w_2ceab05
# 9846  ffeaa7a4.jpg  w_b067417
# 9847  ffecec63.jpg  w_8b56cb1
# 9848  fff04277.jpg  w_2dcbf82
# 9849  fffd4260.jpg  w_b9bfd4e
#
# [9850 rows x 2 columns]

# %%
f = open('cropping.txt', 'rt').read()
line_list = f.split('\n')
bbox_dic = {}
for line in tqdm(line_list, total=len(line_list)):
    id_points = line.split(',')
    id, points = id_points[0], np.array(id_points[1:])
    img = cv2.imread('dataset/images/train/' + id)
    h, w = img.shape[0], img.shape[1]
    points = (points.reshape((-1, 2))).astype(int)
    if points.shape[0] != 0:
        x_min, x_max = np.min(points[:, 0]), np.max(points[:, 0])
        y_min, y_max = np.min(points[:, 1]), np.max(points[:, 1])
        bbox = [[(x_min + x_max) / 2 / w, (y_min + y_max) / 2 / h, (x_max - x_min) / w, (y_max - y_min) / h]]
    # train.loc[train['Image'] == id, 'bbox'] = bbox
        bbox_dic[id] = bbox
# train['bbox'] = train['Image'].map(bbox_dic)
bbox_dic = pd.Series(bbox_dic)
train['bbox'] = train['Image'].map(bbox_dic)
# train['Image'].map(bbox_dic)
# Out:
# 100%|██████████| 1200/1200 [00:04<00:00, 293.79it/s]

# %%
train = train.loc[~train['bbox'].isna(), :]
train
# Out:
#              Image         Id  \
# 1     000466c4.jpg  w_1287fbc
# 2     00087b01.jpg  w_da2efe0
# 4     0014cfdf.jpg  w_f22f3e3
# 5     0025e8c2.jpg  w_8b1ca89
# 7     0031c258.jpg  new_whale
# ...            ...        ...
# 9806  feb9ded0.jpg  w_2a939eb
# 9813  ff0d2705.jpg  w_4e52a49
# 9819  ff2c20cc.jpg  w_f6fb689
# 9832  ff8b2ad0.jpg  w_0f20cbc
# 9839  ffbca206.jpg  w_73b26b7
#
#                                                    bbox
# 1     [[0.3861904761904762, 0.525, 0.328571428571428...
# 2     [[0.4957142857142857, 0.5081521739130435, 0.98...
# 4     [[0.49357142857142855, 0.5314070351758794, 0.8...
# 5     [[0.496, 0.47699386503067487, 0.756, 0.3006134...
# 7     [[0.49476190476190474, 0.4934210526315789, 0.9...
# ...                                                 ...
# 9806  [[0.49047619047619045, 0.46936542669584247, 0....
# 9813  [[0.49142857142857144, 0.5216666666666666, 0.9...
# 9819  [[0.4719047619047619, 0.5681818181818182, 0.91...
# 9832  [[0.4942857142857143, 0.49828178694158076, 0.9...
# 9839  [[0.49523809523809526, 0.49496221662468515, 0....
#
# [1200 rows x 3 columns]

# %%
for img_name in tqdm(train['Image']):
    img = cv2.imread('dataset/images/train/' + img_name)
    train.loc[train['Image'] == img_name, 'hight'] = img.shape[0]
    train.loc[train['Image'] == img_name, 'width'] = img.shape[1]
train
# Out:
#   0%|          | 0/1200 [00:00<?, ?it/s]/tmp/ipykernel_861/123064445.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train.loc[train['Image'] == img_name, 'hight'] = img.shape[0]
# /tmp/ipykernel_861/123064445.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train.loc[train['Image'] == img_name, 'width'] = img.shape[1]
# 100%|██████████| 1200/1200 [00:04<00:00, 267.45it/s]
#              Image         Id  \
# 1     000466c4.jpg  w_1287fbc
# 2     00087b01.jpg  w_da2efe0
# 4     0014cfdf.jpg  w_f22f3e3
# 5     0025e8c2.jpg  w_8b1ca89
# 7     0031c258.jpg  new_whale
# ...            ...        ...
# 9806  feb9ded0.jpg  w_2a939eb
# 9813  ff0d2705.jpg  w_4e52a49
# 9819  ff2c20cc.jpg  w_f6fb689
# 9832  ff8b2ad0.jpg  w_0f20cbc
# 9839  ffbca206.jpg  w_73b26b7
#
#                                                    bbox  hight   width
# 1     [[0.3861904761904762, 0.525, 0.328571428571428...  700.0  1050.0
# 2     [[0.4957142857142857, 0.5081521739130435, 0.98...  368.0  1050.0
# 4     [[0.49357142857142855, 0.5314070351758794, 0.8...  398.0   700.0
# 5     [[0.496, 0.47699386503067487, 0.756, 0.3006134...  652.0  1000.0
# 7     [[0.49476190476190474, 0.4934210526315789, 0.9...  456.0  1050.0
# ...                                                 ...    ...     ...
# 9806  [[0.49047619047619045, 0.46936542669584247, 0....  457.0  1050.0
# 9813  [[0.49142857142857144, 0.5216666666666666, 0.9...  600.0  1050.0
# 9819  [[0.4719047619047619, 0.5681818181818182, 0.91...  506.0  1050.0
# 9832  [[0.4942857142857143, 0.49828178694158076, 0.9...  291.0  1050.0
# 9839  [[0.49523809523809526, 0.49496221662468515, 0....  397.0  1050.0
#
# [1200 rows x 5 columns]

# %%
# for idx in tqdm(train.index, total = 1200):
#     label_path = 'dataset/labels/train/' + train.loc[idx, 'Image'][:-3] + 'txt'
#     # print(label_path)
#     # print(label_path)
#     # print(str(train.loc[idx, 'bbox'])[2: -2].replace(',', ''))
#     with open(label_path, 'w') as f:
#         f.write('0 ' + str(train.loc[idx, 'bbox'])[2: -2].replace(',', ''))

# %%
image_path = 'dataset/images/train/' + '0014cfdf.jpg'
img = cv2.imread(image_path)
label_path = 'dataset/labels/train/' + '0014cfdf.txt'
with open(label_path, 'rt') as f:
    annot = f.read()
    annot = np.array(annot.split(' ')[1:])
    annot = [float(a) for a in annot]
    print(annot)
pt1 = [int((annot[0] - annot[2] / 2) * img.shape[1]), int((annot[1] - annot[3] / 2) * img.shape[0])]
pt2 = [int((annot[0] + annot[2] / 2) * img.shape[1]), int((annot[1] + annot[3] / 2) * img.shape[0])]
# Out:
# [0.49357142857142855, 0.5314070351758794, 0.8642857142857143, 0.4748743718592965]

# %%
print(img.shape)
print(pt1, pt2)
# Out:
# (398, 700, 3)
# [42, 117] [648, 306]

# %%
image_path = 'dataset/images/train/' + '0014cfdf.jpg'
img = cv2.imread(image_path)
img = cv2.rectangle(img, pt1, pt2, [255, 0, 0], 2)
plt.imshow(img)

# %%
! python3 'yolov5/train.py' --cfg 'yolov5/whale_config/whale_model_l.yaml' --data 'yolov5/whale_config/wha. le_data.yaml' --device '0' --weight 'yolov5/runs/train/exp5/weights/best.pt' --epochs 300 --batch-size 36
# Out:
# train: weights=yolov5/runs/train/exp5/weights/best.pt, cfg=yolov5/whale_config/whale_model_l.yaml, data=yolov5/whale_config/whale_data.yaml, hyp=yolov5/data/hyps/hyp.scratch-low.yaml, epochs=300, batch_size=36, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=0, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=yolov5/runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# Command 'git fetch origin' timed out after 5 seconds
# YOLOv5 🚀 v7.0-215-ga6659d0 Python-3.8.10 torch-1.10.0+cu113 CUDA:0 (NVIDIA GeForce RTX 4090, 24217MiB)
#
# hyperparameters: lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0
# Comet: run 'pip install comet_ml' to automatically track and visualize YOLOv5 🚀 runs in Comet
# TensorBoard: Start with 'tensorboard --logdir yolov5/runs/train', view at http://localhost:6006/
#
#                  from  n    params  module                                  arguments
#   0                -1  1      7040  models.common.Conv                      [3, 64, 6, 2, 2]
#   1                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   2                -1  3    156928  models.common.C3                        [128, 128, 3]
#   3                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   4                -1  6   1118208  models.common.C3                        [256, 256, 6]
#   5                -1  1   1180672  models.common.Conv                      [256, 512, 3, 2]
#   6                -1  9   6433792  models.common.C3                        [512, 512, 9]
#   7                -1  1   4720640  models.common.Conv                      [512, 1024, 3, 2]
#   8                -1  3   9971712  models.common.C3                        [1024, 1024, 3]
#   9                -1  1   2624512  models.common.SPPF                      [1024, 1024, 5]
#  10                -1  1    525312  models.common.Conv                      [1024, 512, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  3   2757632  models.common.C3                        [1024, 512, 3, False]
#  14                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  3    690688  models.common.C3                        [512, 256, 3, False]
#  18                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  3   2495488  models.common.C3                        [512, 512, 3, False]
#  21                -1  1   2360320  models.common.Conv                      [512, 512, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  3   9971712  models.common.C3                        [1024, 1024, 3, False]
#  24      [17, 20, 23]  1     32310  models.yolo.Detect                      [1, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [256, 512, 1024]]
# whale_model_l summary: 368 layers, 46138294 parameters, 46138294 gradients, 108.2 GFLOPs
#
# Transferred 612/613 items from yolov5/runs/train/exp5/weights/best.pt
# AMP: checks passed ✅
# optimizer: SGD(lr=0.01) with parameter groups 101 weight(decay=0.0), 104 weight(decay=0.0005625000000000001), 104 bias
# train: Scanning /root/autodl-tmp/whale_tail/dataset/labels/train.cache... 1200 i
# val: Scanning /root/autodl-tmp/whale_tail/dataset/labels/train.cache... 1200 ima
#
# AutoAnchor: 1.82 anchors/target, 1.000 Best Possible Recall (BPR). Current anchors are a good fit to dataset ✅
# Plotting labels to yolov5/runs/train/exp10/labels.jpg...
# Image sizes 640 train, 640 val
# Using 8 dataloader workers
# Logging results to yolov5/runs/train/exp10
# Starting training for 300 epochs...
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       0/299      21.4G    0.01031   0.003444          0          7        640: 1
#                  Class     Images  Instances          P          R      mAP50   fatal: unable to access 'https://github.com/ultralytics/yolov5.git/': Failed to connect to github.com port 443: Connection timed out
#                  Class     Images  Instances          P          R      mAP50
#                    all       9850       1200      0.129      0.939      0.168      0.163
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       1/299      19.4G    0.01158   0.003517          0         11        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       9850       1200      0.126       0.98      0.164       0.15
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       2/299      19.4G    0.01376   0.003622          0         10        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       9850       1200      0.124      0.934      0.152      0.134
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       3/299      19.4G    0.01684   0.003734          0         16        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       9850       1200      0.123      0.934      0.148      0.124
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       4/299      19.4G    0.01659   0.003669          0          9        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       9850       1200      0.124      0.932      0.137      0.118
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       5/299      19.4G    0.01709   0.003749          0          9        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       9850       1200      0.123      0.943      0.134      0.116
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       6/299      19.4G    0.01761   0.003686          0          5        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       9850       1200      0.123      0.863      0.132      0.108
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       7/299      19.4G    0.01915   0.003718          0         11        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       9850       1200      0.122      0.922      0.141      0.122
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       8/299      19.4G    0.01639   0.003714          0          7        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       9850       1200      0.122      0.915      0.126       0.11
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       9/299      19.4G    0.01669   0.003825          0         11        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       9850       1200      0.122      0.951      0.127      0.109
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      10/299      19.4G    0.01739   0.003755          0         10        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       9850       1200      0.122      0.943      0.132      0.121
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      11/299      19.4G    0.01569   0.003853          0          8        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       9850       1200      0.126      0.944      0.138      0.125
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      12/299      19.4G    0.01558   0.003739          0          3        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       9850       1200      0.123      0.954      0.141      0.126
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      13/299      19.4G    0.01463   0.003721          0          7        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       9850       1200      0.124      0.924      0.147      0.132
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      14/299      19.4G    0.01571   0.003689          0          5        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       9850       1200      0.123      0.963      0.136      0.117
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      15/299      19.4G    0.01541   0.003714          0          8        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       9850       1200      0.123      0.978      0.132      0.118
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      16/299      19.4G    0.01531   0.003774          0         12        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       9850       1200      0.123      0.962      0.143      0.125
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      17/299      19.4G    0.01505   0.003711          0          8        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       9850       1200      0.124      0.966      0.146      0.134
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      18/299      19.4G    0.01603   0.003739          0          9        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       9850       1200      0.123      0.943      0.138      0.122
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      19/299      19.4G     0.0149   0.003789          0          7        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       9850       1200      0.123      0.953      0.129      0.116
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      20/299      19.4G    0.01506   0.003702          0         11        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       9850       1200      0.124      0.954      0.138      0.121
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      21/299      19.4G    0.01471   0.003758          0          4        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       9850       1200      0.123      0.963      0.134      0.119
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      22/299      19.4G     0.0151   0.003763          0          7        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       9850       1200      0.124      0.963      0.138      0.125
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      23/299      19.4G    0.01496   0.003726          0          7        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       9850       1200      0.123      0.963      0.142      0.126
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      24/299      19.4G    0.01564   0.003755          0         12        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       9850       1200      0.123      0.967      0.137      0.124
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      25/299      19.4G     0.0136   0.003726          0          9        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       9850       1200      0.124      0.975      0.142      0.129
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      26/299      19.4G    0.01548   0.003778          0          9        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       9850       1200      0.125      0.874      0.141      0.128
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      27/299      19.4G    0.01406   0.003769          0          6        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       9850       1200      0.123      0.978      0.142      0.131
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      28/299      19.4G    0.01384   0.003749          0          8        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       9850       1200      0.124      0.964      0.144      0.134
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      29/299      19.4G    0.01329   0.003633          0         12        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       9850       1200      0.123      0.979      0.132      0.119
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      30/299      19.4G    0.01455   0.003739          0         11        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       9850       1200      0.123      0.982      0.141      0.127
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      31/299      19.4G    0.01411   0.003753          0          8        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       9850       1200      0.124      0.978      0.144      0.132
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      32/299      19.4G    0.01343   0.003725          0          4        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       9850       1200      0.124      0.962      0.138      0.126
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      33/299      19.4G    0.01345   0.003774          0          6        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       9850       1200      0.123      0.977       0.14      0.129
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      34/299      19.4G    0.01379   0.003713          0          7        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       9850       1200      0.123      0.968      0.141      0.129
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      35/299      19.4G    0.01395   0.003652          0          6        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       9850       1200      0.123      0.983      0.139      0.128
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      36/299      19.4G    0.01335    0.00377          0          9        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       9850       1200      0.124      0.976      0.137      0.126
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      37/299      19.4G    0.01353   0.003754          0          7        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       9850       1200      0.123      0.979      0.142      0.132
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      38/299      19.4G     0.0139   0.003658          0          8        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       9850       1200      0.123      0.982      0.141      0.131
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      39/299      19.4G    0.01448   0.003729          0         12        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       9850       1200      0.124      0.972      0.142      0.132
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      40/299      19.4G      0.014   0.003698          0         10        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       9850       1200      0.123      0.968      0.143      0.131
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      41/299      19.4G     0.0143   0.003753          0          9        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       9850       1200      0.124      0.981      0.138      0.127
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      42/299      19.4G    0.01317   0.003638          0          6        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       9850       1200      0.124      0.969      0.141      0.129
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      43/299      19.4G    0.01359   0.003803          0          9        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       9850       1200      0.123      0.973      0.135      0.127
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      44/299      19.4G    0.01437   0.003762          0          7        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       9850       1200      0.123      0.968      0.141      0.129
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      45/299      19.4G    0.01406   0.003723          0          9        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       9850       1200      0.123       0.98      0.141      0.131
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      46/299      19.4G    0.01283   0.003723          0          9        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       9850       1200      0.123      0.976      0.147      0.137
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      47/299      19.4G    0.01375   0.003673          0          5        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       9850       1200      0.123      0.971       0.15      0.139
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      48/299      19.4G    0.01305   0.003695          0          5        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       9850       1200      0.124      0.973      0.148       0.14
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      49/299      19.4G    0.01334   0.003713          0          5        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       9850       1200      0.124      0.978      0.138      0.131
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      50/299      19.4G    0.01331   0.003731          0          6        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       9850       1200      0.124      0.972      0.143      0.135
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      51/299      19.4G    0.01344   0.003697          0         11        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       9850       1200      0.123      0.973      0.142      0.133
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      52/299      19.4G    0.01405   0.003703          0          7        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       9850       1200      0.123      0.978      0.136      0.127
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      53/299      19.4G    0.01344   0.003693          0          5        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       9850       1200      0.124      0.975      0.149       0.14
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      54/299      19.4G    0.01357   0.003666          0         11        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       9850       1200      0.124      0.972      0.146      0.139
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      55/299      19.4G    0.01337   0.003749          0         10        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       9850       1200      0.123      0.983      0.145      0.137
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      56/299      19.4G    0.01333   0.003678          0          4        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       9850       1200      0.123      0.984       0.15      0.141
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      57/299      19.4G     0.0128   0.003742          0          9        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       9850       1200      0.123      0.982      0.142      0.135
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      58/299      19.4G    0.01329   0.003672          0          8        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       9850       1200      0.123      0.981      0.146      0.139
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      59/299      19.4G    0.01337   0.003644          0          7        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       9850       1200      0.124      0.993      0.151      0.143
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      60/299      19.4G    0.01229   0.003675          0          7        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       9850       1200      0.124      0.994       0.14      0.133
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      61/299      19.4G    0.01321   0.003592          0          6        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       9850       1200      0.124      0.984      0.148       0.14
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      62/299      19.4G    0.01232   0.003821          0          7        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       9850       1200      0.124      0.976      0.148      0.141
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      63/299      19.4G    0.01314   0.003719          0          8        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       9850       1200      0.123      0.983      0.143      0.136
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      64/299      19.4G    0.01319   0.003691          0          4        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       9850       1200      0.124      0.983      0.141      0.125
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      65/299      19.4G    0.01318   0.003684          0          7        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       9850       1200      0.124      0.993      0.144      0.132
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      66/299      19.4G    0.01287   0.003748          0          6        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       9850       1200      0.124      0.989      0.149       0.14
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      67/299      19.4G    0.01268   0.003631          0          5        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       9850       1200      0.123      0.977      0.143      0.136
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      68/299      19.4G    0.01392    0.00375          0          6        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       9850       1200      0.124      0.975      0.143      0.136
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      69/299      19.4G    0.01405   0.003705          0          8        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       9850       1200      0.123       0.98      0.146       0.14
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      70/299      19.4G    0.01262   0.003585          0          5        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       9850       1200      0.124      0.976      0.147      0.141
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      71/299      19.4G    0.01222   0.003627          0          9        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       9850       1200      0.124      0.974      0.147      0.141
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      72/299      19.4G    0.01312   0.003585          0          6        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       9850       1200      0.124      0.977      0.149      0.143
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      73/299      19.4G    0.01288   0.003714          0          7        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       9850       1200      0.123      0.977      0.153      0.147
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      74/299      19.4G    0.01309     0.0037          0         11        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       9850       1200      0.124      0.976      0.152      0.146
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      75/299      19.4G     0.0131   0.003664          0          8        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       9850       1200      0.123      0.984      0.148      0.142
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      76/299      19.4G    0.01218   0.003669          0          3        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       9850       1200      0.123      0.981      0.151      0.145
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      77/299      19.4G    0.01255   0.003579          0          9        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       9850       1200      0.123       0.98      0.149      0.143
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      78/299      19.4G    0.01292   0.003666          0         10        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       9850       1200      0.124      0.977      0.147      0.141
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      79/299      19.4G    0.01288   0.003677          0         11        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       9850       1200      0.124      0.979      0.149      0.143
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      80/299      19.4G    0.01334   0.003756          0         10        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       9850       1200      0.124      0.977      0.154      0.147
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      81/299      19.4G    0.01194     0.0036          0          7        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       9850       1200      0.124      0.978      0.152      0.147
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      82/299      19.4G    0.01287    0.00368          0          9        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       9850       1200      0.124      0.982       0.15      0.145
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      83/299      19.4G    0.01262   0.003599          0          9        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all       9850       1200      0.124      0.988       0.15      0.145
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      84/299      19.4G     0.0129   0.003627          0          4        640: 1
#                  Class     Images  Instances          P          R      mAP50   ^C
#                  Class     Images  Instances          P          R      mAP50
# Traceback (most recent call last):
#   File "yolov5/train.py", line 647, in <module>
#     main(opt)
#   File "yolov5/train.py", line 536, in main
#     train(opt.hyp, opt, device, callbacks)
#   File "yolov5/train.py", line 359, in train
#     results, maps, _ = validate.run(data_dict,
#   File "/root/miniconda3/lib/python3.8/site-packages/torch/autograd/grad_mode.py", line 28, in decorate_context
#     return func(*args, **kwargs)
#   File "/root/autodl-tmp/whale_tail/yolov5/val.py", line 230, in run
#     labels = targets[targets[:, 0] == si, 1:]
# KeyboardInterrupt
# Exception in thread Thread-4:
# Traceback (most recent call last):
#   File "/root/miniconda3/lib/python3.8/threading.py", line 932, in _bootstrap_inner
#     self.run()
#   File "/root/miniconda3/lib/python3.8/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "/root/miniconda3/lib/python3.8/site-packages/torch/utils/data/_utils/pin_memory.py", line 28, in _pin_memory_loop
#     r = in_queue.get(timeout=MP_STATUS_CHECK_INTERVAL)
#   File "/root/miniconda3/lib/python3.8/multiprocessing/queues.py", line 116, in get
#     return _ForkingPickler.loads(res)
#   File "/root/miniconda3/lib/python3.8/site-packages/torch/multiprocessing/reductions.py", line 289, in rebuild_storage_fd
#     fd = df.detach()
#   File "/root/miniconda3/lib/python3.8/multiprocessing/resource_sharer.py", line 57, in detach
#     with _resource_sharer.get_connection(self._id) as conn:
#   File "/root/miniconda3/lib/python3.8/multiprocessing/resource_sharer.py", line 87, in get_connection
#     c = Client(address, authkey=process.current_process().authkey)
#   File "/root/miniconda3/lib/python3.8/multiprocessing/connection.py", line 502, in Client
#     c = SocketClient(address)
#   File "/root/miniconda3/lib/python3.8/multiprocessing/connection.py", line 630, in SocketClient
#     s.connect(address)
# FileNotFoundError: [Errno 2] No such file or directory
